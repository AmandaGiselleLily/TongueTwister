# %%
import pandas as pd

run_file = pd.read_csv(r'C:\Users\Motor Control Lab\Documents\GitHub\TongueTwister\Experiments\TT1\stimuli.csv',sep=',')

# %%
x=run_file.drop(['sentence'],axis=1)
x

x.to_csv(r'C:\Users\Motor Control Lab\Documents\GitHub\TongueTwister\Experiments\TT1\stimuli\sentences.tsv',sep='\t',index=False)

# %%
x
# Out:
#   syll1 syll2  syll3  syll4    syll5    syll6     syll7
# 0   how  much  would      a    chuck       if  thrilled
# 1   the  thir     ti  three  thieves  thought    throne
# 2    pi   ter    pie    per   picked     peck       out
# 3   pro   per    caw    fee      pot  through     thurs
# 4  less   ser    leh   ther      neh      ver       day
# 5  imah   jin   airy    mih      naw      juh       jur
